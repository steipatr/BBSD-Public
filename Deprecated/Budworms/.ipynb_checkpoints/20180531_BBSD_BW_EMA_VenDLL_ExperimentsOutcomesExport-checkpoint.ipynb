# %%
#import ALL THE THINGS

import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import os
import feather
import datetime

from ema_workbench import (Model, 
                           RealParameter, 
                           Constant,
                           TimeSeriesOutcome,
                           perform_experiments, 
                           ema_logging, 
                           save_results,
                           perform_experiments, 
                           ema_logging)

#from ema_workbench.em_framework import samplers

from ema_workbench.connectors.vensim import VensimModel

#from ema_workbench.em_framework.evaluators import LHS, MC

import ema_workbench.analysis.pairs_plotting as pairs
import ema_workbench.analysis.plotting as emaplt

# turn on logging
ema_logging.log_to_stderr(ema_logging.INFO)
# Out:
# C:\Users\Patrick\Anaconda3\lib\site-packages\ema_workbench\em_framework\optimization.py:29: ImportWarning: platypus based optimization not available
#   warnings.warn("platypus based optimization not available", ImportWarning)
# C:\Users\Patrick\Anaconda3\lib\site-packages\ema_workbench\connectors\__init__.py:18: ImportWarning: netlogo connector not available
#   warnings.warn("netlogo connector not available", ImportWarning)
# C:\Users\Patrick\Anaconda3\lib\importlib\_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)
# C:\Users\Patrick\Anaconda3\lib\importlib\_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)
# <Logger EMA (DEBUG)>

# %%
def export_outcomes(outcomes, location = './Data/' ):
    """takes EMA outcomes and exports all time series for each outcome of interest as a .feather dataframe for easy
    import into R. Arguments: export_outcomes(name of EMA outcomes dict, desired save location). Save location must exist,
    defaults to './Data/'.
    
    """
     
    today = datetime.date.today()
    datestr = (str(today))  
    
    keylist = list(outcomes.keys())
    
    for k in keylist:
        df_temp = pd.DataFrame(outcomes[k])
        df_temp = df_temp.copy()
        path = location + datestr + k.replace(' ','') + '.feather'
        feather.write_dataframe(df_temp,path)

    return("Done.");

# %% [markdown]
# ## Values and response surface for r, k
# <img src="StrogatzBudworms_rk_combined.PNG" alt="r, k from Strogatz" style="width: 700px;"/>

# %%
#define experiment parameters
uncertainties = [
                #RealParameter('k', 2,30), #dimensionless carrying capacity for budworms #fixed for now TODO
                RealParameter('r max',0.4,0.7), #initial r value
                RealParameter('drift',0,0.35) #amount by which r is reduced at time "step time"
            ]

outcomes =  [
                TimeSeriesOutcome('x'), #budworm population
                TimeSeriesOutcome('c'), #budworm creation
                TimeSeriesOutcome('p') #budworm predation/loss
            ]

constants = [
                Constant('xi', 2), #initial budworm population
                Constant('k', 10), #dimensionless carrying capacity for budworms
                Constant('use rsin',1), #use step function for r instead of constant base value
                Constant('r base val',0.4), #constant base value for r
                
                Constant('drift time',40), #fixed time at which drift of r sets in, has no effect on system behavior
                Constant('drift duration',20) #time it takes r to drift from max to min
                
            ]

# %%
wd = r'./'
model = VensimModel("StrogatzBudworms", wd=wd, model_file=r'201805310123_BBSD_BW_StrogatzBudworms_rk_rsinsweep.vpm')

model.uncertainties = uncertainties
model.outcomes = outcomes
model.constants = constants

# %%
#run experiments
#TODO parallel
results = perform_experiments(model, 200)

experiments, outcomes = results
# Out:
# [MainProcess/INFO] performing 200 scenarios * 1 policies * 1 model(s) = 200 experiments
# [MainProcess/INFO] performing experiments sequentially
# [MainProcess/INFO] 20 cases completed
# [MainProcess/INFO] 40 cases completed
# [MainProcess/INFO] 60 cases completed
# [MainProcess/INFO] 80 cases completed
# [MainProcess/INFO] 100 cases completed
# [MainProcess/INFO] 120 cases completed
# [MainProcess/INFO] 140 cases completed
# [MainProcess/INFO] 160 cases completed
# [MainProcess/INFO] 180 cases completed
# [MainProcess/INFO] 200 cases completed
# [MainProcess/INFO] experiments finished

# %%
figure = emaplt.lines(results,density=u'kde') #show lines, and end state density
plt.rcParams["figure.figsize"] = (18,10)
plt.show() #show figure

# %%
#experiments, outcomes = results
#print(experiments) #<class 'numpy.ndarray'>
#print(type(experiments.item(2))) #<class 'tuple'>

#experiments is an array of tuples, where each tuple is one experiment input set

# %%
#print(type(outcomes)) #<class 'dict'>
#print(type(outcomes['Deceased Population'])) #<class 'numpy.ndarray'>
#print(type(outcomes['Deceased Population'][1])) #<class 'numpy.ndarray'>
#print(type(outcomes['Deceased Population'][1].item(1))) #<class 'float'>


'''outcomes is a dict of output variables (key) and output value arrays (value), where each output value array has
the shape (number of runs) * (run duration / time step = total steps). Each run (or row) is an array of floats,
where each row is the time series output of a specific simulation run for the associated variable, and each float
is the value of that variable at a specific step or time in the simulation run.'''
# Out:
# 'outcomes is a dict of output variables (key) and output value arrays (value), where each output value array has\nthe shape (number of runs) * (run duration / time step = total steps). Each run (or row) is an array of floats,\nwhere each row is the time series output of a specific simulation run for the associated variable, and each float\nis the value of that variable at a specific step or time in the simulation run.'

# %%
export_outcomes(outcomes)
# Out:
# 'Done.'

# %%
print(experiments)
# Out:
# [(0.2101741 , 0.52258411, 1205, 'None', 'StrogatzBudworms')
#  (0.33084941, 0.47680166, 1206, 'None', 'StrogatzBudworms')
#  (0.14574781, 0.45745981, 1207, 'None', 'StrogatzBudworms')
#  (0.34802734, 0.57807268, 1208, 'None', 'StrogatzBudworms')
#  (0.19523804, 0.43437429, 1209, 'None', 'StrogatzBudworms')
#  (0.12915925, 0.54175   , 1210, 'None', 'StrogatzBudworms')
#  (0.01229909, 0.40763595, 1211, 'None', 'StrogatzBudworms')
#  (0.08528464, 0.47367493, 1212, 'None', 'StrogatzBudworms')
#  (0.02368382, 0.52120278, 1213, 'None', 'StrogatzBudworms')
#  (0.0680526 , 0.69717319, 1214, 'None', 'StrogatzBudworms')
#  (0.13169024, 0.54446896, 1215, 'None', 'StrogatzBudworms')
#  (0.11806833, 0.68113134, 1216, 'None', 'StrogatzBudworms')
#  (0.1902068 , 0.48294408, 1217, 'None', 'StrogatzBudworms')
#  (0.07473545, 0.65447989, 1218, 'None', 'StrogatzBudworms')
#  (0.18039131, 0.6852016 , 1219, 'None', 'StrogatzBudworms')
#  (0.10159255, 0.62395198, 1220, 'None', 'StrogatzBudworms')
#  (0.34273977, 0.45484376, 1221, 'None', 'StrogatzBudworms')
#  (0.29301856, 0.62166235, 1222, 'None', 'StrogatzBudworms')
#  (0.29206131, 0.46696588, 1223, 'None', 'StrogatzBudworms')
#  (0.08716859, 0.55301   , 1224, 'None', 'StrogatzBudworms')
#  (0.32431005, 0.44516038, 1225, 'None', 'StrogatzBudworms')
#  (0.0652536 , 0.69899847, 1226, 'None', 'StrogatzBudworms')
#  (0.32872461, 0.42331227, 1227, 'None', 'StrogatzBudworms')
#  (0.14910694, 0.53933919, 1228, 'None', 'StrogatzBudworms')
#  (0.17830737, 0.61668876, 1229, 'None', 'StrogatzBudworms')
#  (0.27607457, 0.66652608, 1230, 'None', 'StrogatzBudworms')
#  (0.34056868, 0.54319817, 1231, 'None', 'StrogatzBudworms')
#  (0.15994022, 0.56062379, 1232, 'None', 'StrogatzBudworms')
#  (0.20341809, 0.66488151, 1233, 'None', 'StrogatzBudworms')
#  (0.03340709, 0.50277152, 1234, 'None', 'StrogatzBudworms')
#  (0.02892407, 0.52647371, 1235, 'None', 'StrogatzBudworms')
#  (0.15150879, 0.59504586, 1236, 'None', 'StrogatzBudworms')
#  (0.18509825, 0.46172174, 1237, 'None', 'StrogatzBudworms')
#  (0.16572701, 0.65635768, 1238, 'None', 'StrogatzBudworms')
#  (0.25046514, 0.62556075, 1239, 'None', 'StrogatzBudworms')
#  (0.17065991, 0.54055592, 1240, 'None', 'StrogatzBudworms')
#  (0.13876482, 0.6923637 , 1241, 'None', 'StrogatzBudworms')
#  (0.02603692, 0.51352953, 1242, 'None', 'StrogatzBudworms')
#  (0.00750771, 0.42849066, 1243, 'None', 'StrogatzBudworms')
#  (0.20714939, 0.45869719, 1244, 'None', 'StrogatzBudworms')
#  (0.1537561 , 0.41946011, 1245, 'None', 'StrogatzBudworms')
#  (0.10332637, 0.67547318, 1246, 'None', 'StrogatzBudworms')
#  (0.23484035, 0.69652068, 1247, 'None', 'StrogatzBudworms')
#  (0.33759158, 0.58918148, 1248, 'None', 'StrogatzBudworms')
#  (0.34965215, 0.57655592, 1249, 'None', 'StrogatzBudworms')
#  (0.04309811, 0.58578642, 1250, 'None', 'StrogatzBudworms')
#  (0.25834427, 0.64781856, 1251, 'None', 'StrogatzBudworms')
#  (0.06145511, 0.48188297, 1252, 'None', 'StrogatzBudworms')
#  (0.14505505, 0.50996238, 1253, 'None', 'StrogatzBudworms')
#  (0.31213862, 0.51130982, 1254, 'None', 'StrogatzBudworms')
#  (0.21665616, 0.45196286, 1255, 'None', 'StrogatzBudworms')
#  (0.11437884, 0.57471255, 1256, 'None', 'StrogatzBudworms')
#  (0.32329576, 0.53501095, 1257, 'None', 'StrogatzBudworms')
#  (0.09680971, 0.49168057, 1258, 'None', 'StrogatzBudworms')
#  (0.17987716, 0.53163666, 1259, 'None', 'StrogatzBudworms')
#  (0.07940298, 0.47937398, 1260, 'None', 'StrogatzBudworms')
#  (0.29561565, 0.49505977, 1261, 'None', 'StrogatzBudworms')
#  (0.30201453, 0.5694555 , 1262, 'None', 'StrogatzBudworms')
#  (0.31942464, 0.58719601, 1263, 'None', 'StrogatzBudworms')
#  (0.12449164, 0.53402868, 1264, 'None', 'StrogatzBudworms')
#  (0.28132036, 0.48400429, 1265, 'None', 'StrogatzBudworms')
#  (0.03703868, 0.63101293, 1266, 'None', 'StrogatzBudworms')
#  (0.05762934, 0.67845656, 1267, 'None', 'StrogatzBudworms')
#  (0.29623481, 0.44441999, 1268, 'None', 'StrogatzBudworms')
#  (0.19317678, 0.64183122, 1269, 'None', 'StrogatzBudworms')
#  (0.22922436, 0.49340902, 1270, 'None', 'StrogatzBudworms')
#  (0.07634717, 0.58893068, 1271, 'None', 'StrogatzBudworms')
#  (0.22141042, 0.46545377, 1272, 'None', 'StrogatzBudworms')
#  (0.09199411, 0.52565708, 1273, 'None', 'StrogatzBudworms')
#  (0.27220749, 0.60873358, 1274, 'None', 'StrogatzBudworms')
#  (0.2524902 , 0.6436147 , 1275, 'None', 'StrogatzBudworms')
#  (0.22020161, 0.62001688, 1276, 'None', 'StrogatzBudworms')
#  (0.02703996, 0.57267548, 1277, 'None', 'StrogatzBudworms')
#  (0.23074887, 0.63298238, 1278, 'None', 'StrogatzBudworms')
#  (0.04506081, 0.68435825, 1279, 'None', 'StrogatzBudworms')
#  (0.05088341, 0.60473236, 1280, 'None', 'StrogatzBudworms')
#  (0.0699437 , 0.6769889 , 1281, 'None', 'StrogatzBudworms')
#  (0.10517953, 0.51971459, 1282, 'None', 'StrogatzBudworms')
#  (0.12322334, 0.66976787, 1283, 'None', 'StrogatzBudworms')
#  (0.09037277, 0.47989901, 1284, 'None', 'StrogatzBudworms')
#  (0.30291071, 0.48818783, 1285, 'None', 'StrogatzBudworms')
#  (0.30910558, 0.50753693, 1286, 'None', 'StrogatzBudworms')
#  (0.13041459, 0.5509996 , 1287, 'None', 'StrogatzBudworms')
#  (0.06403525, 0.69286912, 1288, 'None', 'StrogatzBudworms')
#  (0.2373698 , 0.50911652, 1289, 'None', 'StrogatzBudworms')
#  (0.26690679, 0.42643132, 1290, 'None', 'StrogatzBudworms')
#  (0.24720406, 0.48993697, 1291, 'None', 'StrogatzBudworms')
#  (0.18594685, 0.43031618, 1292, 'None', 'StrogatzBudworms')
#  (0.16641749, 0.62761144, 1293, 'None', 'StrogatzBudworms')
#  (0.21461724, 0.61539883, 1294, 'None', 'StrogatzBudworms')
#  (0.3452039 , 0.59488329, 1295, 'None', 'StrogatzBudworms')
#  (0.24251289, 0.42054579, 1296, 'None', 'StrogatzBudworms')
#  (0.24915707, 0.58077158, 1297, 'None', 'StrogatzBudworms')
#  (0.28403106, 0.62318838, 1298, 'None', 'StrogatzBudworms')
#  (0.12084411, 0.47122901, 1299, 'None', 'StrogatzBudworms')
#  (0.29809011, 0.44865504, 1300, 'None', 'StrogatzBudworms')
#  (0.0405208 , 0.50005665, 1301, 'None', 'StrogatzBudworms')
#  (0.08244051, 0.63455594, 1302, 'None', 'StrogatzBudworms')
#  (0.01863892, 0.41664538, 1303, 'None', 'StrogatzBudworms')
#  (0.09499214, 0.64033236, 1304, 'None', 'StrogatzBudworms')
#  (0.04788822, 0.45552957, 1305, 'None', 'StrogatzBudworms')
#  (0.27034216, 0.40224769, 1306, 'None', 'StrogatzBudworms')
#  (0.32656395, 0.49709772, 1307, 'None', 'StrogatzBudworms')
#  (0.09435606, 0.65938763, 1308, 'None', 'StrogatzBudworms')
#  (0.02215002, 0.51457008, 1309, 'None', 'StrogatzBudworms')
#  (0.33396981, 0.59057292, 1310, 'None', 'StrogatzBudworms')
#  (0.22509643, 0.63638899, 1311, 'None', 'StrogatzBudworms')
#  (0.13684199, 0.66170937, 1312, 'None', 'StrogatzBudworms')
#  (0.28247392, 0.65147033, 1313, 'None', 'StrogatzBudworms')
#  (0.32943648, 0.65690405, 1314, 'None', 'StrogatzBudworms')
#  (0.19241074, 0.52869884, 1315, 'None', 'StrogatzBudworms')
#  (0.07710148, 0.40479404, 1316, 'None', 'StrogatzBudworms')
#  (0.2231246 , 0.45391926, 1317, 'None', 'StrogatzBudworms')
#  (0.24537071, 0.58277308, 1318, 'None', 'StrogatzBudworms')
#  (0.01451015, 0.66735496, 1319, 'None', 'StrogatzBudworms')
#  (0.2118613 , 0.40607109, 1320, 'None', 'StrogatzBudworms')
#  (0.30701713, 0.59674041, 1321, 'None', 'StrogatzBudworms')
#  (0.265763  , 0.56778458, 1322, 'None', 'StrogatzBudworms')
#  (0.23338972, 0.44220904, 1323, 'None', 'StrogatzBudworms')
#  (0.13510843, 0.55151502, 1324, 'None', 'StrogatzBudworms')
#  (0.00293837, 0.61851967, 1325, 'None', 'StrogatzBudworms')
#  (0.00117672, 0.55747364, 1326, 'None', 'StrogatzBudworms')
#  (0.20115006, 0.57920803, 1327, 'None', 'StrogatzBudworms')
#  (0.10029832, 0.6459329 , 1328, 'None', 'StrogatzBudworms')
#  (0.11071209, 0.65211949, 1329, 'None', 'StrogatzBudworms')
#  (0.11689042, 0.68776295, 1330, 'None', 'StrogatzBudworms')
#  (0.34418904, 0.63744366, 1331, 'None', 'StrogatzBudworms')
#  (0.19898685, 0.49136863, 1332, 'None', 'StrogatzBudworms')
#  (0.27694309, 0.46386317, 1333, 'None', 'StrogatzBudworms')
#  (0.00460741, 0.60336034, 1334, 'None', 'StrogatzBudworms')
#  (0.32074638, 0.52396841, 1335, 'None', 'StrogatzBudworms')
#  (0.31566091, 0.68241363, 1336, 'None', 'StrogatzBudworms')
#  (0.2730355 , 0.50392963, 1337, 'None', 'StrogatzBudworms')
#  (0.07241219, 0.61019647, 1338, 'None', 'StrogatzBudworms')
#  (0.30085564, 0.67094538, 1339, 'None', 'StrogatzBudworms')
#  (0.10954802, 0.63049943, 1340, 'None', 'StrogatzBudworms')
#  (0.18273794, 0.40445424, 1341, 'None', 'StrogatzBudworms')
#  (0.24149485, 0.54591772, 1342, 'None', 'StrogatzBudworms')
#  (0.04933317, 0.62905301, 1343, 'None', 'StrogatzBudworms')
#  (0.07141013, 0.67188686, 1344, 'None', 'StrogatzBudworms')
#  (0.08839082, 0.41226874, 1345, 'None', 'StrogatzBudworms')
#  (0.23265497, 0.43783726, 1346, 'None', 'StrogatzBudworms')
#  (0.25951406, 0.46955938, 1347, 'None', 'StrogatzBudworms')
#  (0.20218578, 0.47559077, 1348, 'None', 'StrogatzBudworms')
#  (0.33478955, 0.40057696, 1349, 'None', 'StrogatzBudworms')
#  (0.16868628, 0.67436779, 1350, 'None', 'StrogatzBudworms')
#  (0.14727516, 0.4105064 , 1351, 'None', 'StrogatzBudworms')
#  (0.14046318, 0.53799756, 1352, 'None', 'StrogatzBudworms')
#  (0.01666574, 0.44743878, 1353, 'None', 'StrogatzBudworms')
#  (0.15907514, 0.51667054, 1354, 'None', 'StrogatzBudworms')
#  (0.1574501 , 0.40986911, 1355, 'None', 'StrogatzBudworms')
#  (0.22700394, 0.41509624, 1356, 'None', 'StrogatzBudworms')
#  (0.31090576, 0.60567367, 1357, 'None', 'StrogatzBudworms')
#  (0.26404984, 0.57056805, 1358, 'None', 'StrogatzBudworms')
#  (0.20532266, 0.64640942, 1359, 'None', 'StrogatzBudworms')
#  (0.03212102, 0.61433458, 1360, 'None', 'StrogatzBudworms')
#  (0.09801303, 0.43180004, 1361, 'None', 'StrogatzBudworms')
#  (0.04556538, 0.56414186, 1362, 'None', 'StrogatzBudworms')
#  (0.2892844 , 0.55491344, 1363, 'None', 'StrogatzBudworms')
#  (0.05921513, 0.47259214, 1364, 'None', 'StrogatzBudworms')
#  (0.16228665, 0.53202576, 1365, 'None', 'StrogatzBudworms')
#  (0.25549464, 0.5586598 , 1366, 'None', 'StrogatzBudworms')
#  (0.23809918, 0.5984185 , 1367, 'None', 'StrogatzBudworms')
#  (0.14341379, 0.49871428, 1368, 'None', 'StrogatzBudworms')
#  (0.19625607, 0.58380817, 1369, 'None', 'StrogatzBudworms')
#  (0.27956752, 0.42527704, 1370, 'None', 'StrogatzBudworms')
#  (0.03864168, 0.43585217, 1371, 'None', 'StrogatzBudworms')
#  (0.26161929, 0.42884292, 1372, 'None', 'StrogatzBudworms')
#  (0.15440124, 0.649928  , 1373, 'None', 'StrogatzBudworms')
#  (0.12713864, 0.4362915 , 1374, 'None', 'StrogatzBudworms')
#  (0.11369998, 0.46092463, 1375, 'None', 'StrogatzBudworms')
#  (0.01954431, 0.4396493 , 1376, 'None', 'StrogatzBudworms')
#  (0.13300379, 0.42135692, 1377, 'None', 'StrogatzBudworms')
#  (0.06049973, 0.44166403, 1378, 'None', 'StrogatzBudworms')
#  (0.05498886, 0.69547278, 1379, 'None', 'StrogatzBudworms')
#  (0.17653179, 0.68990436, 1380, 'None', 'StrogatzBudworms')
#  (0.2865122 , 0.66324445, 1381, 'None', 'StrogatzBudworms')
#  (0.0540455 , 0.55986579, 1382, 'None', 'StrogatzBudworms')
#  (0.3391622 , 0.54905701, 1383, 'None', 'StrogatzBudworms')
#  (0.25563105, 0.54733383, 1384, 'None', 'StrogatzBudworms')
#  (0.21708815, 0.5661616 , 1385, 'None', 'StrogatzBudworms')
#  (0.16437337, 0.50107696, 1386, 'None', 'StrogatzBudworms')
#  (0.03131033, 0.52987385, 1387, 'None', 'StrogatzBudworms')
#  (0.30618766, 0.5711018 , 1388, 'None', 'StrogatzBudworms')
#  (0.26851962, 0.48625832, 1389, 'None', 'StrogatzBudworms')
#  (0.17487282, 0.46850023, 1390, 'None', 'StrogatzBudworms')
#  (0.31474811, 0.66085596, 1391, 'None', 'StrogatzBudworms')
#  (0.24464178, 0.60057917, 1392, 'None', 'StrogatzBudworms')
#  (0.00979392, 0.51760105, 1393, 'None', 'StrogatzBudworms')
#  (0.31779622, 0.68902893, 1394, 'None', 'StrogatzBudworms')
#  (0.17194333, 0.45080712, 1395, 'None', 'StrogatzBudworms')
#  (0.28818512, 0.50556807, 1396, 'None', 'StrogatzBudworms')
#  (0.08081805, 0.60249012, 1397, 'None', 'StrogatzBudworms')
#  (0.11976307, 0.63902652, 1398, 'None', 'StrogatzBudworms')
#  (0.00579668, 0.61172172, 1399, 'None', 'StrogatzBudworms')
#  (0.10693656, 0.5931118 , 1400, 'None', 'StrogatzBudworms')
#  (0.20921552, 0.60810025, 1401, 'None', 'StrogatzBudworms')
#  (0.03665793, 0.41399709, 1402, 'None', 'StrogatzBudworms')
#  (0.01082601, 0.56336712, 1403, 'None', 'StrogatzBudworms')
#  (0.18744542, 0.67918894, 1404, 'None', 'StrogatzBudworms')]

# %%
df_expt = pd.DataFrame(experiments)
df_expt = df_expt.copy()
df_expt.iloc[:,0:2].head()
# Out:
#       drift     r max
# 0  0.210174  0.522584
# 1  0.330849  0.476802
# 2  0.145748  0.457460
# 3  0.348027  0.578073
# 4  0.195238  0.434374

# %%
import datetime
df_expt = pd.DataFrame(experiments) #convert experiments (array of tuples) into df
df_expt = df_expt.copy() #self-copy to circumvent errors
path = "./Data/" + str(datetime.date.today()) + "Experiments" + '.feather' #create path for saving
feather.write_dataframe(df_expt.iloc[:,0:2],path) #feather it!
